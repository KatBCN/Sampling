# %% [markdown]
# # <font color='#d50283'>IT Academy - Data Science Itinerary</font>
# ## Sprint 6 Task 1 - Sampling Methods
# ### Assignment by: Kat Weissman
#
# #### Python Learning Objectives:
# - Preprocess
# - Sampling

# %% [markdown]
# *Recommended learning resources:*
# - https://www.scribbr.com/methodology/sampling-methods/
# - https://www.statisticshowto.com/probability-and-statistics/sampling-in-statistics/
# - https://towardsdatascience.com/the-5-sampling-algorithms-every-data-scientist-need-to-know-43c7bc11d17c
# - https://www.khanacademy.org/math/statistics-probability/designing-studies/sampling-methods-stats/a/sampling-methods-review
# - https://www.khanacademy.org/math/statistics-probability/designing-studies
# - https://www.analyticsvidhya.com/blog/2019/09/data-scientists-guide-8-types-of-sampling-techniques/

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Level 1
#
# ### Exercise 1
# Choose a sports-themed dataset you like. Perform a sampling of the data generating a simple random sample and a systematic sample.

# %% [markdown]
# IFSC Combined Climbing Competition Results:
# - https://www.kaggle.com/brkurzawa/ifsc-sport-climbing-competition-results?select=combined_results.csv

# %% [markdown]
# #### Data Exploration

# %%
data_link = '/Users/kat/Library/Mobile Documents/com~apple~CloudDocs/IT Academy/Data Science Itinerary/Sprint 6 - Sampling Methods/combined_results.csv'
df = pd.read_csv(data_link)

# %%
#Show number of rows and columns in dataframe
df.shape
# Out:
# (879, 15)

# %%
#Save and show column names
column_names = list(df.columns)
column_names
# Out:
# ['Competition Title',
#  'Competition Date',
#  'FIRST',
#  'LAST',
#  'Nation',
#  'Rank',
#  'Qualification lead',
#  'Qualification speed',
#  'Qualification boulder',
#  'Final lead',
#  'Final speed',
#  'Final boulder',
#  'Points',
#  'Final Points',
#  'Category']

# %%
#Display first 10 rows of dataframe
df.head(10)
# Out:
#                                    Competition Title      Competition Date  \
# 0  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 1  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 2  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 3  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 4  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 5  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 6  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 7  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 8  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 9  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
#
#      FIRST        LAST Nation  Rank Qualification lead Qualification speed  \
# ...

# %%
#Display last 10 rows of dataframe
df.tail(10)
# Out:
#                                      Competition Title   Competition Date  \
# 869  IFSC Climbing World Championships Combined - I...  16 September 2018
# 870  IFSC Climbing World Championships Combined - I...  16 September 2018
# 871  IFSC Climbing World Championships Combined - I...  16 September 2018
# 872  IFSC Climbing World Championships Combined - I...  16 September 2018
# 873  IFSC Climbing World Championships Combined - I...  16 September 2018
# 874  IFSC Climbing World Championships Combined - I...  16 September 2018
# 875  IFSC Climbing World Championships Combined - I...  16 September 2018
# 876  IFSC Climbing World Championships Combined - I...  16 September 2018
# 877  IFSC Climbing World Championships Combined - I...  16 September 2018
# 878  IFSC Climbing World Championships Combined - I...  16 September 2018
#
#        FIRST      LAST Nation  Rank Qualification lead Qualification speed  \
# 869  Jessica      PILZ    AUT     3              10 1.            11.9986.
# ...

# %%
#Checking dataset variables
df.dtypes
# Out:
# Competition Title         object
# Competition Date          object
# FIRST                     object
# LAST                      object
# Nation                    object
# Rank                       int64
# Qualification lead        object
# Qualification speed       object
# Qualification boulder     object
# Final lead                object
# Final speed               object
# Final boulder             object
# Points                   float64
# Final Points             float64
# Category                  object
# dtype: object

# %%
#View summary statistics of each variable.
for v in df.columns:
        print ("\n" + v)
        print(df[v].describe())
        print ()
# Out:
# Competition Title
# count                                                   879
# unique                                                    4
# top       IFSC Youth World Championships -  Arco (ITA) 2...
# freq                                                    600
# Name: Competition Title, dtype: object
#
#
# Competition Date
# count                      879
# unique                       4
# top       22  - 31 August 2019
# freq                       600
# Name: Competition Date, dtype: object
#
#
# FIRST
# count     879
# unique    260
# top       Kai
# freq        9
# Name: FIRST, dtype: object
#
#
# LAST
# count     879
# unique    263
# top       KIM
# freq       15
# Name: LAST, dtype: object
#
#
# Nation
# count     879
# unique     45
# top       JPN
# freq       81
# Name: Nation, dtype: object
#
#
# Rank
# count    879.000000
# mean      15.228669
# std        9.839315
# min        1.000000
# 25%        7.000000
# 50%       14.000000
# 75%       23.000000
# ...

# %% [markdown]
# Some variables which I would expect to be numerical are not, such as the qualifications and finals for Lead and Speed events. This is due to the different tournaments recording results in a different way. Data for multiple rounds has been combined into a single column. In some cases, the column contains both the numerical result for the event and the athlete's rank.

# %%
competition_counts = df['Competition Title'].value_counts()
print (competition_counts)

#Creating pie chart for distribution of number of records per competition
#define data
data = competition_counts
labels = competition_counts.index

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]

#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()
# Out:
# IFSC Youth World Championships -  Arco (ITA) 2019                    600
# IFSC PanAmerican Championship (L, S, B, C) - Guayaquil (ECU) 2018    123
# IFSC Climbing World Championships Combined - Hachioji (JPN) 2019     120
# IFSC Climbing World Championships Combined - Innsbruck (AUT) 2018     36
# Name: Competition Title, dtype: int64

# %% [markdown]
# #### Sampling by group

# %% [markdown]
# First, I would like to see a sample of the complete scoring format for each competition. For this, I need to see example scores from athletes that made it to finals and don't have any NA's.
#
# [pandas.core.groupby.DataFrameGroupBy.sample](https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.sample.html)
#
# DataFrameGroupBy.sample(n=None, frac=None, replace=False, weights=None, random_state=None)

# %%
dropNA_df = df.dropna()
grouped_df = dropNA_df.groupby('Competition Title')
grouped_sample_df = grouped_df.sample(n=1) #includes 1 random sample from each group
grouped_sample_df
# Out:
#                                      Competition Title  \
# 222  IFSC Climbing World Championships Combined - H...
# 575  IFSC Climbing World Championships Combined - I...
# 827  IFSC PanAmerican Championship (L, S, B, C) - G...
#
#            Competition Date      FIRST        LAST Nation  Rank  \
# 222    18  - 21 August 2019     Rishat  KHAIBULLIN    KAZ     3
# 575       16 September 2018        Sol          SA    KOR     2
# 827  21  - 26 November 2018  Valentina      AGUADO    ARG     2
#
#     Qualification lead Qualification speed Qualification boulder Final lead  \
# 222             27+16.             5.8631.             1T1z4317.      22 5.
# 575               5 6.             9.8062.              1T1z776.      23+6.
# 827                 2.                  5.                    1.      Top1.
#
#     Final speed Final boulder  Points  Final Points  Category
# 222     5.9151.      0T1z028.   272.0          40.0  combined
# ...

# %% [markdown]
# In theory, the above code should have worked, but it appears that there is an NA in every row of the Youth World Competition, so it didn't appear in my results, so I need to check again.

# %%
grouped_df = df.groupby('Competition Title')
grouped_sample_df = grouped_df.sample(n=1) #includes 1 random sample from each group
grouped_sample_df
# Out:
#                                      Competition Title  \
# 517  IFSC Climbing World Championships Combined - H...
# 291  IFSC Climbing World Championships Combined - I...
# 274  IFSC PanAmerican Championship (L, S, B, C) - G...
# 452  IFSC Youth World Championships -  Arco (ITA) 2...
#
#            Competition Date       FIRST      LAST Nation  Rank  \
# 517    18  - 21 August 2019      Meichi  NARASAKI    JPN     5
# 291       16 September 2018       Tomoa  NARASAKI    JPN     5
# 274  21  - 26 November 2018    Valentin   STERNIK    ARG    22
# 452    22  - 31 August 2019  jose tomas   LEDESMA    CHI    30
#
#     Qualification lead Qualification speed Qualification boulder Final lead  \
# 517             31 10.             6.7768.             3T4z1185.      21 6.
# 291             37 11.                  6.                    4.      34 4.
# 274                22.                 18.                   17.        NaN
# ...

# %% [markdown]
# #### Simple Random Sampling

# %% [markdown]
# [pandas.DataFrame.sample](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sample.html)
#
# DataFrame.sample(n=None, frac=None, replace=False, weights=None, random_state=None, axis=None, ignore_index=False)

# %%
simple_random_df = df.sample(100)
simple_random_df.head(15)
# Out:
#                                      Competition Title  \
# 853  IFSC PanAmerican Championship (L, S, B, C) - G...
# 721  IFSC Youth World Championships -  Arco (ITA) 2...
# 41   IFSC Youth World Championships -  Arco (ITA) 2...
# 847  IFSC PanAmerican Championship (L, S, B, C) - G...
# 423  IFSC Youth World Championships -  Arco (ITA) 2...
# 822  IFSC Climbing World Championships Combined - H...
# 350  IFSC Youth World Championships -  Arco (ITA) 2...
# 253  IFSC PanAmerican Championship (L, S, B, C) - G...
# 283  IFSC Climbing World Championships Combined - I...
# 288  IFSC Climbing World Championships Combined - I...
# 553  IFSC PanAmerican Championship (L, S, B, C) - G...
# 374  IFSC Youth World Championships -  Arco (ITA) 2...
# 222  IFSC Climbing World Championships Combined - H...
# 274  IFSC PanAmerican Championship (L, S, B, C) - G...
# 18   IFSC Youth World Championships -  Arco (ITA) 2...
#
#            Competition Date       FIRST         LAST Nation  Rank  \
# ...

# %%
simple_competition_counts = simple_random_df['Competition Title'].value_counts()
print (simple_competition_counts)

#Creating pie chart for distribution of number of records per competition
#define data
data = simple_competition_counts
labels = simple_competition_counts.index

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]

#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()
# Out:
# IFSC Youth World Championships -  Arco (ITA) 2019                    70
# IFSC PanAmerican Championship (L, S, B, C) - Guayaquil (ECU) 2018    14
# IFSC Climbing World Championships Combined - Hachioji (JPN) 2019     12
# IFSC Climbing World Championships Combined - Innsbruck (AUT) 2018     4
# Name: Competition Title, dtype: int64

# %% [markdown]
# We can see in the simple random sample that the proportion of records from each competition has changed slightly. The 2019 Youth World Championships increased from 68% to 70%, the 2019 World Championship decreased from 14% to 12%, the 2018 Pan American Championships and the 2018 World Championships maintained their proportions.

# %% [markdown]
# #### Systematic Sample
#
# Before starting the systematic sample, I want to randomly shuffle the rows and reset the index in case there is a built-in order that could bias the results.

# %%
shuffled_df = df.sample(frac=1,ignore_index=True)
shuffled_df.shape
# Out:
# (879, 15)

# %% [markdown]
# The shape is the same as the original df, so the shuffle should have worked. I will check the first 5 rows to make sure they are different than before.

# %%
shuffled_df.head()
# Out:
#                                    Competition Title      Competition Date  \
# 0  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 1  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 2  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 3  IFSC Climbing World Championships Combined - H...  18  - 21 August 2019
# 4  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
#
#            FIRST      LAST Nation  Rank Qualification lead  \
# 0        Joaquin   SQUELLA    CHI    27                29.
# 1           Vana   PICCINI    CRO    14                14.
# 2  Thorben Perry     BLOEM    GER     5                15.
# 3          Janja  GARNBRET    SLO     1              35+8.
# 4        Dimitar     RUSEV    BUL    20                17.
#
#   Qualification speed Qualification boulder Final lead Final speed  \
# 0                 17.                   30.        NaN         NaN
# ...

# %%
#create sampling index that takes every 8th athlete
sampling_index = list(range(7,878,8))
len(sampling_index)
# Out:
# 109

# %%
systematic_df = shuffled_df.iloc[sampling_index]
systematic_df.head()
# Out:
#                                     Competition Title        Competition Date  \
# 7   IFSC Youth World Championships -  Arco (ITA) 2...    22  - 31 August 2019
# 15  IFSC Climbing World Championships Combined - H...    18  - 21 August 2019
# 23  IFSC Youth World Championships -  Arco (ITA) 2...    22  - 31 August 2019
# 31  IFSC PanAmerican Championship (L, S, B, C) - G...  21  - 26 November 2018
# 39  IFSC Youth World Championships -  Arco (ITA) 2...    22  - 31 August 2019
#
#         FIRST               LAST Nation  Rank Qualification lead  \
# 7   Athanasia             LIOUNI    GRE    28                27.
# 15     Shauna             COXSEY    GBR     3              36+3.
# 23    Ignacia  MELLADO QUINTEROS    CHI    24                14.
# 31     Hector              MEJIA    GUA    28                27.
# 39     Annika          LORENTZEN    DEN    33                37.
#
#    Qualification speed Qualification boulder Final lead Final speed  \
# ...

# %%
systematic_df.tail()
# Out:
#                                      Competition Title  \
# 839  IFSC Youth World Championships -  Arco (ITA) 2...
# 847  IFSC Youth World Championships -  Arco (ITA) 2...
# 855  IFSC PanAmerican Championship (L, S, B, C) - G...
# 863  IFSC Youth World Championships -  Arco (ITA) 2...
# 871  IFSC PanAmerican Championship (L, S, B, C) - G...
#
#            Competition Date      FIRST          LAST Nation  Rank  \
# 839    22  - 31 August 2019  Eva Maria  HAMMELMÜLLER    AUT     5
# 847    22  - 31 August 2019        Zoi   PALTATSIDOU    GRE    35
# 855  21  - 26 November 2018      Isaac       ESTEVEZ    ECU    15
# 863    22  - 31 August 2019      Julia          LOTZ    AUT     2
# 871  21  - 26 November 2018    Muykuay         SILVA    CHI     8
#
#     Qualification lead Qualification speed Qualification boulder Final lead  \
# 839                 6.                  3.                    5.        NaN
# 847                32.                 36.                   31.        NaN
# ...

# %%
systematic_competition_counts = systematic_df['Competition Title'].value_counts()
print (systematic_competition_counts)

#Creating pie chart for distribution of number of records per competition
#define data
data = systematic_competition_counts
labels = systematic_competition_counts.index

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]

#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()
# Out:
# IFSC Youth World Championships -  Arco (ITA) 2019                    75
# IFSC PanAmerican Championship (L, S, B, C) - Guayaquil (ECU) 2018    17
# IFSC Climbing World Championships Combined - Hachioji (JPN) 2019     12
# IFSC Climbing World Championships Combined - Innsbruck (AUT) 2018     5
# Name: Competition Title, dtype: int64

# %% [markdown]
# We can see in the systematic sample that the proportion of records from each competition has also changed slightly. The 2019 Youth World Championships increased from 68% to 69%, the 2018 Pan American Championships increased from 14% to 16%, the 2019 World Championship decreased from 14% to 11%,  and the 2018 World Championships increased from 4% to 5%.

# %% [markdown]
# ### Level 2
# ### Exercise 2
# Continue with the sports theme data set and generate a stratified sample and a sample using SMOTE (Synthetic Minority Oversampling Technique).

# %% [markdown]
# #### Stratified Sample
#
# [sklearn.model_selection.train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)
#
# sklearn.model_selection.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)
#
# I want to create a sample that maintains the proportions of results from each competition.

# %%
from sklearn.model_selection import train_test_split

y = df.pop('Competition Title')
X = df
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    stratify=y,
                                                    test_size=0.11)

# %%
stratified_df = pd.DataFrame(X_test)
stratified_df.insert(0, 'Competition Title', y_test)
stratified_df.head()
# Out:
#                                      Competition Title      Competition Date  \
# 614  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 695  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 334  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 476  IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
# 28   IFSC Youth World Championships -  Arco (ITA) 2...  22  - 31 August 2019
#
#       FIRST       LAST Nation  Rank Qualification lead Qualification speed  \
# 614  Eszter    RIESING    HUN    29                30.                 26.
# 695  Milosz      BUJAK    POL    14                28.                  3.
# 334  Carmen  CONTRERAS    CHI     7                 9.                  3.
# 476  Klemen      NOVAK    SLO    18                 8.                 26.
# 28   Eszter    RIESING    HUN    29                30.                 26.
#
# ...

# %%
stratified_df.shape
# Out:
# (97, 15)

# %%
stratified_competition_counts = stratified_df['Competition Title'].value_counts()
print (stratified_competition_counts)

#Creating pie chart for distribution of number of records per competition
#define data
data = stratified_competition_counts
labels = stratified_competition_counts.index

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]

#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()
# Out:
# IFSC Youth World Championships -  Arco (ITA) 2019                    66
# IFSC PanAmerican Championship (L, S, B, C) - Guayaquil (ECU) 2018    14
# IFSC Climbing World Championships Combined - Hachioji (JPN) 2019     13
# IFSC Climbing World Championships Combined - Innsbruck (AUT) 2018     4
# Name: Competition Title, dtype: int64

# %% [markdown]
# As desired, the proportions of records from each competition in the stratified sample best match the proportions in the original data set. The percentage shown in the pie chart for the 2019 World Championship is 13% instead of 14%, and the pie chart only totals to 99% instead of 100% which is not so important.

# %% [markdown]
# #### SMOTE (Synthetic Minority Oversampling Technique)

# %% [markdown]
# [SMOTE documentation](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.SMOTE.html)
#
# "Under-sampling of the majority (normal) class has been proposed as a good means of increasing the sensitivity of a classifier to the minority class. This paper shows that a combination of our method of over-sampling the minority (abnormal) class and under-sampling the majority (normal) class can achieve better classifier performance (in ROC space) than only under-sampling the majority class." - N. V. Chawla, K. W. Bowyer, L. O.Hall, W. P. Kegelmeyer, “SMOTE: synthetic minority over-sampling technique,” Journal of artificial intelligence research, 321-357, 2002.
#
# Article available on proquest through UPC Library: https://www-proquest-com.recursos.biblioteca.upc.edu/scholarly-journals/smote-synthetic-minority-over-sampling-technique/docview/2554138630/se-2?accountid=15300

# %%
#from imblearn.over_sampling import SMOTE

#smote = SMOTE(ratio='minority')
#X_sm, y_sm = smote.fit_sample(X, y)

# %% [markdown]
# ### Level 3
# ### Exercise 3
# Continue with the sports theme dataset and generate a sample using the Reservoir sampling method.

# %% [markdown]
# #### Reservoir Sampling
#
# Reference:
# - https://en.wikipedia.org/wiki/Reservoir_sampling
#
# The following code block is taken from [The 5 Sampling Algorithms every Data Scientist need to know](https://towardsdatascience.com/the-5-sampling-algorithms-every-data-scientist-need-to-know-43c7bc11d17c)

# %%
import random
def generator(max):
    number = 1
    while number < max:
        number += 1
        yield number
# Create as stream generator
stream = generator(10000)
# Doing Reservoir Sampling from the stream
k=5
reservoir = []
for i, element in enumerate(stream):
    if i+1<= k:
        reservoir.append(element)
    else:
        probability = k/(i+1)
        if random.random() < probability:
            # Select item in stream and remove one of the k items already selected
             reservoir[random.choice(range(0,k))] = element
print(reservoir)
#------------------------------------
#[1369, 4108, 9986, 828, 5589]
# Out:
# [6201, 9960, 5274, 8710, 2225]

# %% [markdown]
# I slightly modify the code to be compatible for sampling from my data set.

# %%
# Setting stream to number of rows in data frame to sample.
stream = generator(len(df))
# Doing Reservoir Sampling from the stream
#Setting k = to size of desired sample
k=100
reservoir = []
for i, element in enumerate(stream):
    if i+1<= k:
        reservoir.append(element)
    else:
        probability = k/(i+1)
        if random.random() < probability:
            # Select item in stream and remove one of the k items already selected
             reservoir[random.choice(range(0,k))] = element

# %%
#reset the dataframe to the original data set.
df = pd.read_csv(data_link)

#create a new dataframe with using the index created by the reservoir sampling
reservoir_df = df.iloc[reservoir]
reservoir_df.head()
# Out:
#                                      Competition Title  \
# 2    IFSC Youth World Championships -  Arco (ITA) 2...
# 567  IFSC PanAmerican Championship (L, S, B, C) - G...
# 869  IFSC Climbing World Championships Combined - I...
# 654  IFSC Youth World Championships -  Arco (ITA) 2...
# 137  IFSC Youth World Championships -  Arco (ITA) 2...
#
#            Competition Date        FIRST      LAST Nation  Rank  \
# 2      22  - 31 August 2019        Emily  PHILLIPS    GBR     3
# 567  21  - 26 November 2018     Valentin   STERNIK    ARG    22
# 869       16 September 2018      Jessica      PILZ    AUT     3
# 654    22  - 31 August 2019  Sohha Ninad     DIWAN    IND    34
# 137    22  - 31 August 2019       Joseph  XIBERRAS    GBR     8
#
#     Qualification lead Qualification speed Qualification boulder Final lead  \
# 2                   2.                  5.                    4.        NaN
# 567                22.                 18.                   17.        NaN
# ...

# %%
reservoir_competition_counts = reservoir_df['Competition Title'].value_counts()
print (reservoir_competition_counts)

#Creating pie chart for distribution of number of records per competition
#define data
data = reservoir_competition_counts
labels = reservoir_competition_counts.index

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]

#create pie chart
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()
# Out:
# IFSC Youth World Championships -  Arco (ITA) 2019                    71
# IFSC PanAmerican Championship (L, S, B, C) - Guayaquil (ECU) 2018    14
# IFSC Climbing World Championships Combined - Hachioji (JPN) 2019     11
# IFSC Climbing World Championships Combined - Innsbruck (AUT) 2018     4
# Name: Competition Title, dtype: int64

# %% [markdown]
# We can see in the reservoir sample that the proportion of records from each competition has also changed slightly. The 2019 Youth World Championships increased from 68% to 71%, the 2018 Pan American Championships maintained its proportion, the 2019 World Championship decreased from 14% to 11%,  and the 2018 World Championships maintained its proportion.
